# %% [markdown]
# # ***Your Life***

# %% [markdown]
# ### This project will talking about you, your life, habits, coustums. Like a biography

# %%
print("Hello, Welcome")
name = input("What's your name? ")
print(f"Hi {name};")
ready = input("Are you ready for the questions?")
if ready == "Yes":
    print("Let's go!")
    age = int(input(f"How old are you {name}? "))
    nacionality = input(f"Where are you from {name}")
    profession = input("What's your profession? ")
    habits =  input("What's your habits? ")
    hobbies = input("What do you like in your free time? ")
    skills = input("What's your skils? ")
    morning = input("How are your mornings? ")
    afternoon = input("What do you make in your afternons? ")
    night = input("And, how are your nights?")
    print("loading your biography...")
    print(f"The {name}:")
    print(f"A people from {nacionality}, have {age} years old, working like {profession}.") 
    print(f"Like make some things, like: {hobbies}, and is very good in {skills}.")
    print(f"The daily routine:")
    print(f"In the mornings are usually {morning}.")
    print(f"In the afternoon usually make {afternoon}.")
    print("And at nights custom make {night}.")
elif ready == "No":
    print("Get ready for the quetions and after return here.")
else:
    print("Invalid response. Enter only: 'Yes' or 'No'. ")
# Out:
# Hello, Welcome
# Hi Davi;
# Let's go!
# loading your biography...
# The Davi:
# A people from Brasil, have 16 years old, working like Mechanic.
# Like make some things, like: play videogames and watch TV, and is very good in leadership, mathematics.
# The daily routine:
# In the mornings are usually I have breakfest and go to school.
# In the afternoon usually make I play videogames, ride a bike and watch TV.
# And at nights custom make {night}.
